# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
import timeit

pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.options.display.float_format = '{:,.4f}'.format

# %%
helper_dir = '../helper'

# %run {helper_dir}/utils.py
# %run {helper_dir}/rolling_funcs.py
# %run {helper_dir}/rolling_apply_funcs.py
# %run {helper_dir}/rolling_calc_beta.py   # super fast beta calculation

# %% [markdown]
# ## Make some large data

# %%
num_sec_dfs, num_periods = 10000, 480

dates = pd.date_range('1995-12-31', periods=num_periods, freq='M', name='Date')
stocks = pd.DataFrame(data=np.random.rand(num_periods, num_sec_dfs), index=dates,
                      columns=['s{:04d}'.format(i) for i in range(num_sec_dfs)]).pct_change().dropna()
market = pd.DataFrame(data=np.random.rand(num_periods), index=dates, 
                      columns=['Market']).pct_change().dropna()
rets = stocks.join(market)

# %%
stocks.head()
# Out:
#              s0000   s0001   s0002   s0003   s0004   s0005   s0006  ...  \
# Date                                                                ...
# 1996-01-31 -0.4170 -0.8087 -0.1262  0.4313  0.2713  7.5734 -0.1859  ...
# 1996-02-29  0.0678  2.8339 -0.4521  0.8239 -0.0275 -0.3340 -0.5956  ...
# 1996-03-31 -0.7101  1.2186  1.8050 -0.0518 -0.1300 -0.7163  2.1421  ...
# 1996-04-30  4.0682  0.0462 -0.4999 -0.9466 -0.5576 -0.2221 -0.8269  ...
# 1996-05-31  0.0326 -0.7567  0.0539  9.7919  0.7413  3.9235  4.2968  ...
#
#              s9993   s9994   s9995   s9996   s9997   s9998   s9999
# Date
# 1996-01-31  0.3530 -0.7320  0.7611  0.7108 -0.1700  1.3290 -0.2942
# 1996-02-29  0.0296 11.5064 -0.2647 -0.6271 -0.9468  1.2059  0.0905
# 1996-03-31 -0.1175 -0.2209 -0.1098 -0.1930 18.2286 -0.8276 -0.8006
# 1996-04-30  0.1484  0.4351  0.3432  0.0810  0.8590  6.7228  6.4918
# 1996-05-31 -0.7520 -0.5217  0.0501  0.4294 -0.2384 -0.6531  0.0865
#
# [5 rows x 10000 columns]

# %%
market.head()
# Out:
#             Market
# Date
# 1996-01-31  0.0325
# 1996-02-29  0.1505
# 1996-03-31 -0.0414
# 1996-04-30 -0.7863
# 1996-05-31 -0.8236

# %%
rets.head()
# Out:
#              s0000   s0001   s0002   s0003   s0004   s0005   s0006  ...  \
# Date                                                                ...
# 1996-01-31 -0.4170 -0.8087 -0.1262  0.4313  0.2713  7.5734 -0.1859  ...
# 1996-02-29  0.0678  2.8339 -0.4521  0.8239 -0.0275 -0.3340 -0.5956  ...
# 1996-03-31 -0.7101  1.2186  1.8050 -0.0518 -0.1300 -0.7163  2.1421  ...
# 1996-04-30  4.0682  0.0462 -0.4999 -0.9466 -0.5576 -0.2221 -0.8269  ...
# 1996-05-31  0.0326 -0.7567  0.0539  9.7919  0.7413  3.9235  4.2968  ...
#
#              s9994   s9995   s9996   s9997   s9998   s9999  Market
# Date
# 1996-01-31 -0.7320  0.7611  0.7108 -0.1700  1.3290 -0.2942  0.0325
# 1996-02-29 11.5064 -0.2647 -0.6271 -0.9468  1.2059  0.0905  0.1505
# 1996-03-31 -0.2209 -0.1098 -0.1930 18.2286 -0.8276 -0.8006 -0.0414
# 1996-04-30  0.4351  0.3432  0.0810  0.8590  6.7228  6.4918 -0.7863
# 1996-05-31 -0.5217  0.0501  0.4294 -0.2384 -0.6531  0.0865 -0.8236
#
# [5 rows x 10001 columns]

# %% [markdown]
# ## Our function and statsmodels should give the same result. Let's check.

# %%
import statsmodels.api as sm

X = sm.add_constant(market)

tot_diff = 0 # should still be zero after the loop
for yvar in stocks.columns:
    y = stocks[yvar]
    results = sm.OLS(y,X).fit()
    beta_statsmod = results.params['Market']
    beta_mine = calc_beta(y, market['Market'])
    tot_diff += abs(beta_statsmod - beta_mine)
assert tot_diff < 1e-8

# %% [markdown]
# ## Calculate rolling beta of each stock against the market

# %%
ndays = 30

# %%
betas_00 = rolling_calc_beta(stocks, market, ndays)

# %%
betas_01 = roll(rets, ndays).apply(lambda x: calc_beta(x.iloc[:, 0], x['Market']))
betas_02 = pd.concat([pd.Series(calc_beta(subdf.iloc[:, 0], subdf['Market']), index=[subdf.index[-1]]) for subdf in groll(rets, ndays)])
betas_03 = rolling_apply_pd(stocks.iloc[:, 0], market['Market'], ndays, calc_beta)
betas_04 = rolling_apply_np(stocks.iloc[:, 0], market['Market'], ndays, calc_beta)

# %%
print(betas_00.dropna().head().iloc[:,0], '\n\n')
print(betas_01.head(), '\n\n')
print(betas_02.head(), '\n\n')
print(betas_03.dropna().head(), '\n\n')
print(betas_04.dropna().head(), '\n\n')
# Out:
# Date
# 1998-06-30   -0.1236
# 1998-07-31   -0.1187
# 1998-08-31    0.0531
# 1998-09-30    0.0431
# 1998-10-31    0.0668
# Freq: M, Name: s0000, dtype: float64
#
#
# Date
# 1998-06-30   -0.1236
# 1998-07-31   -0.1187
# 1998-08-31    0.0531
# 1998-09-30    0.0431
# 1998-10-31    0.0668
# dtype: float64
#
#
# 1998-06-30   -0.1236
# 1998-07-31   -0.1187
# 1998-08-31    0.0531
# 1998-09-30    0.0431
# 1998-10-31    0.0668
# dtype: float64
#
#
# Date
# 1998-06-30   -0.1236
# 1998-07-31   -0.1187
# 1998-08-31    0.0531
# 1998-09-30    0.0431
# 1998-10-31    0.0668
# Freq: M, dtype: float64
#
#
# Date
# 1998-06-30   -0.1236
# 1998-07-31   -0.1187
# 1998-08-31    0.0531
# 1998-09-30    0.0431
# 1998-10-31    0.0668
# Freq: M, dtype: float64

# %%
print(betas_00.dropna().tail().iloc[:,0], '\n\n')
print(betas_01.tail(), '\n\n')
print(betas_02.tail(), '\n\n')
print(betas_03.dropna().tail(), '\n\n')
print(betas_04.dropna().tail(), '\n\n')
# Out:
# Date
# 2035-07-31   0.0265
# 2035-08-31   0.0263
# 2035-09-30   0.0283
# 2035-10-31   0.0256
# 2035-11-30   0.0579
# Freq: M, Name: s0000, dtype: float64
#
#
# Date
# 2035-07-31   0.0265
# 2035-08-31   0.0263
# 2035-09-30   0.0283
# 2035-10-31   0.0256
# 2035-11-30   0.0579
# dtype: float64
#
#
# 2035-07-31   0.0265
# 2035-08-31   0.0263
# 2035-09-30   0.0283
# 2035-10-31   0.0256
# 2035-11-30   0.0579
# dtype: float64
#
#
# Date
# 2035-07-31   0.0265
# 2035-08-31   0.0263
# 2035-09-30   0.0283
# 2035-10-31   0.0256
# 2035-11-30   0.0579
# Freq: M, dtype: float64
#
#
# Date
# 2035-07-31   0.0265
# 2035-08-31   0.0263
# 2035-09-30   0.0283
# 2035-10-31   0.0256
# 2035-11-30   0.0579
# Freq: M, dtype: float64

# %%
print(equal(betas_00.iloc[:,0], betas_01))
print(equal(betas_01, betas_02))
print(equal(betas_02, betas_03))
print(equal(betas_03, betas_04))
# Out:
# True
# True
# True
# True

# %% [markdown]
# ### Remark: all methods give the same results. Let's compare their speed.

# %%
# %%timeit
betas_00 = rolling_calc_beta(stocks, market, ndays)
# Out:
# 1.33 s ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### On this large dataset with 10,000 stocks (columns), our `rolling_calc_beta()` only took 1.3s, while the other methods took forever that I had to kill the runs before they could finish.

# %%
# %%timeit
betas_04 = pd.concat([rolling_apply_np(stocks.iloc[:, j], market['Market'], ndays, calc_beta) for j in range(stocks.shape[1])], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gmlang/CoinDataSchool/experiment/notebooks/rolling_betas.ipynb Cell 20 in 1
# ----> <a href='vscode-notebook-cell:/Users/gmlang/CoinDataSchool/experiment/notebooks/rolling_betas.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('timeit', '', "betas_04 = pd.concat([rolling_apply_np(stocks.iloc[:, j], market['Market'], ndays, calc_beta) for j in range(stocks.shape[1])], axis=1)\n")
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2415 with self.builtin_trap:
#    2416     args = (magic_arg_s, cell)
# -> 2417     result = fn(*args, **kwargs)
#    2418 return result
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/IPython/core/magics/execution.py:1166, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1163         if time_number >= 0.2:
#    1164             break
# -> 1166 all_runs = timer.repeat(repeat, number)
#    1167 best = min(all_runs) / number
#    1168 worst = max(all_runs) / number
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/timeit.py:206, in Timer.repeat(self, repeat, number)
#     204 r = []
#     205 for i in range(repeat):
# --> 206     t = self.timeit(number)
#     207     r.append(t)
#     208 return r
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/IPython/core/magics/execution.py:156, in Timer.timeit(self, number)
#     154 gc.disable()
#     155 try:
# --> 156     timing = self.inner(it, self.timer)
#     157 finally:
#     158     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# File <magic-timeit>:1, in <listcomp>(.0)
#
# File ~/CoinDataSchool/experiment/helper/rolling_apply_funcs.py:78, in rolling_apply_np(s1, s2, window, func, *args)
#      76 s2_arr = as_strided(s2.values, shape=(l - window + 1, window), strides=(ls, ls))
#      77 for row in range(window-1, l):
# ---> 78     result[row] = func(s1_arr[row - window+1], s2_arr[row - window+1], *args)
#      79 return pd.Series(data=result, index=s1.index)
#
# File ~/CoinDataSchool/experiment/helper/rolling_calc_beta.py:13, in calc_beta(y, x)
#      11 def calc_beta(y: np.ndarray, x: np.ndarray):
#      12     x = np.vstack((np.ones_like(x), x)) # add a column of 1's, intercept
# ---> 13     b = np.linalg.pinv(x.dot(x.T)).dot(x).dot(y)
#      14     return b[1]
#
# File <__array_function__ internals>:180, in pinv(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/numpy/linalg/linalg.py:2001, in pinv(a, rcond, hermitian)
#    1998 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2000 # discard small singular values
# -> 2001 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#    2002 large = s > cutoff
#    2003 s = divide(1, s, where=large, out=s)
#
# File <__array_function__ internals>:179, in amax(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.8/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2672, in _amax_dispatcher(a, axis, out, keepdims, initial, where)
#    2668             return ptp(axis=axis, out=out, **kwargs)
#    2669     return _methods._ptp(a, axis=axis, out=out, **kwargs)
# -> 2672 def _amax_dispatcher(a, axis=None, out=None, keepdims=None, initial=None,
#    2673                      where=None):
#    2674     return (a, out)
#    2677 @array_function_dispatch(_amax_dispatcher)
#    2678 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2679          where=np._NoValue):
#
# KeyboardInterrupt:

# %%
# %%timeit
betas_01 = pd.concat([roll(rets, ndays).apply(lambda x: calc_beta(x.iloc[:, j], x['Market'])) for j in range(stocks.shape[1])], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qq/v47zfw7s1kn38gw67q4v194r0000gn/T/ipykernel_55022/3955504261.py in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "betas_01 = pd.concat([roll(rets, ndays).apply(lambda x: calc_beta(x.iloc[:, j], x['Market'])) for j in range(stocks.shape[1])], axis=1)\n")
#
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2401             with self.builtin_trap:
#    2402                 args = (magic_arg_s, cell)
# -> 2403                 result = fn(*args, **kwargs)
#    2404             return result
#    2405
#
# /usr/local/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# /usr/local/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1167             for index in range(0, 10):
#    1168                 number = 10 ** index
# -> 1169                 time_number = timer.timeit(number)
#    1170                 if time_number >= 0.2:
#    1171                     break
#
# /usr/local/lib/python3.8/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# <magic-timeit> in <listcomp>(.0)
#
# /usr/local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1421         with option_context("mode.chained_assignment", None):
#    1422             try:
# -> 1423                 result = self._python_apply_general(f, self._selected_obj)
#    1424             except TypeError:
#    1425                 # gh-20949
#
# /usr/local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same)
#    1462             data after applying f
#    1463         """
# -> 1464         values, mutated = self.grouper.apply(f, data, self.axis)
#    1465
#    1466         if not_indexed_same is None:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     753         zipped = zip(group_keys, splitter)
#     754
# --> 755         for key, group in zipped:
#     756             group = group.__finalize__(data, method="groupby")
#     757             object.__setattr__(group, "name", key)
#
# /usr/local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in __iter__(self)
#    1221
#    1222     def __iter__(self):
# -> 1223         sdata = self.sorted_data
#    1224
#    1225         if self.ngroups == 0:
#
# /usr/local/lib/python3.8/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in sorted_data(self)
#    1235     @cache_readonly
#    1236     def sorted_data(self) -> NDFrameT:
# -> 1237         return self.data.take(self._sort_idx, axis=self.axis)
#    1238
#    1239     def _chop(self, sdata, slice_obj: slice) -> NDFrame:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3701         self._consolidate_inplace()
#    3702
# -> 3703         new_data = self._mgr.take(
#    3704             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3705         )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify)
#     898
#     899         new_labels = self.axes[axis].take(indexer)
# --> 900         return self.reindex_indexer(
#     901             new_axis=new_labels,
#     902             indexer=indexer,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     690             )
#     691         else:
# --> 692             new_blocks = [
#     693                 blk.take_nd(
#     694                     indexer,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     691         else:
#     692             new_blocks = [
# --> 693                 blk.take_nd(
#     694                     indexer,
#     695                     axis=1,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1137             allow_fill = True
#    1138
# -> 1139         new_values = algos.take_nd(
#    1140             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1141         )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/array_algos/take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     115
#     116     arr = np.asarray(arr)
# --> 117     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     118
#     119
#
# /usr/local/lib/python3.8/site-packages/pandas/core/array_algos/take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     161         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     162     )
# --> 163     func(arr, indexer, out, fill_value)
#     164
#     165     if flip_order:
#
# KeyboardInterrupt:
